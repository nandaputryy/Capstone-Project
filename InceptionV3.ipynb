# %%
 from google.colab import drive
 import os

 drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_dir = '/content/drive/MyDrive/DEBUSA'
# !ls "/content/drive/MyDrive/DEBUSA"
# Out:
# testing  training  validation

# %%
# menentukan direktori
train_dir = os.path.join(base_dir, 'training')
testing_dir = os.path.join(base_dir, 'testing')
validation_dir = os.path.join(base_dir, 'validation')

# %%
# menentukan direktori isi bahan
Apel_dir = os.path.join(train_dir, 'Apel/')
Brokoli_dir = os.path.join(train_dir, 'Brokoli/')
Jeruk_dir = os.path.join(train_dir, 'Jeruk/')
Kangkung_dir = os.path.join(train_dir, 'Kangkung/')
Mangga_dir = os.path.join(train_dir, 'Mangga/')
Pisang_dir = os.path.join(train_dir, 'Pisang/')
Strawberry_dir = os.path.join(train_dir, 'Strawberry/')
Terong_dir = os.path.join(train_dir, 'Terong/')
Toge_dir = os.path.join(train_dir, 'Toge/')
Wortel_dir = os.path.join(train_dir, 'Wortel/')

print("Jumlah data train tiap kelas")
print("Jumlah gambar Apel :", len(os.listdir(Apel_dir)))
print("Jumlah gambar Brokoli :", len(os.listdir(Brokoli_dir)))
print("Jumlah gambar Jeruk :", len(os.listdir(Jeruk_dir)))
print("Jumlah gambar Kangkung :", len(os.listdir(Kangkung_dir)))
print("Jumlah gambar Mangga :", len(os.listdir(Mangga_dir)))
print("Jumlah gambar Pisang :", len(os.listdir(Pisang_dir)))
print("Jumlah gambar Strawberry :", len(os.listdir(Strawberry_dir)))
print("Jumlah gambar Terong :", len(os.listdir(Terong_dir)))
print("Jumlah gambar Toge :", len(os.listdir(Toge_dir)))
print("Jumlah gambar Wortel :", len(os.listdir(Wortel_dir)))
# Out:
# Jumlah data train tiap kelas
# Jumlah gambar Apel : 400
# Jumlah gambar Brokoli : 400
# Jumlah gambar Jeruk : 400
# Jumlah gambar Kangkung : 400
# Jumlah gambar Mangga : 400
# Jumlah gambar Pisang : 400
# Jumlah gambar Strawberry : 400
# Jumlah gambar Terong : 400
# Jumlah gambar Toge : 400
# Jumlah gambar Wortel : 400

# %%
# Direktori isi Training
train_Apel = os.path.join(train_dir, 'Apel/')
train_Brokoli = os.path.join(train_dir, 'Brokoli/')
train_Jeruk = os.path.join(train_dir, 'Jeruk/')
train_Kangkung = os.path.join(train_dir, 'Kangkung/')
train_Mangga = os.path.join(train_dir, 'Mangga/')
train_Pisang = os.path.join(train_dir, 'Pisang/')
train_Strawberry = os.path.join(train_dir, 'Strawberry/')
train_Terong = os.path.join(train_dir, 'Terong/')
train_Toge = os.path.join(train_dir, 'Toge/')
train_Wortel = os.path.join(train_dir, 'Wortel/')

# Direktori isi Validasi
validation_Apel = os.path.join(validation_dir, 'Apel/')
validation_Brokoli = os.path.join(validation_dir, 'Brokoli/')
validation_Jeruk = os.path.join(validation_dir, 'Jeruk/')
validation_Kangkung = os.path.join(validation_dir, 'Kangkung/')
validation_Mangga = os.path.join(validation_dir, 'Mangga/')
validation_Pisang = os.path.join(validation_dir, 'Pisang/')
validation_Strawberry = os.path.join(validation_dir, 'Strawberry/')
validation_Terong = os.path.join(validation_dir, 'Terong/')
validation_Toge = os.path.join(validation_dir, 'Toge/')
validation_Wortel = os.path.join(validation_dir, 'Wortel/')

# Direktori isi Testing
testing_Apel = os.path.join(testing_dir, 'Apel/')
testing_Brokoli = os.path.join(testing_dir, 'Brokoli/')
testing_Jeruk = os.path.join(testing_dir, 'Jeruk/')
testing_Kangkung = os.path.join(testing_dir, 'Kangkung/')
testing_Mangga = os.path.join(testing_dir, 'Mangga/')
testing_Pisang = os.path.join(testing_dir, 'Pisang/')
testing_Strawberry = os.path.join(testing_dir, 'Strawberry/')
testing_Terong = os.path.join(testing_dir, 'Terong/')
testing_Toge = os.path.join(testing_dir, 'Toge/')
testing_Wortel = os.path.join(testing_dir, 'Wortel/')

# %%
#Apel
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Apel')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Brokoli
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Brokoli')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Jeruk
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Jeruk')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Kangkung
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Kangkung')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Mangga
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Mangga')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Pisang
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Pisang')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Strawberry
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Strawberry')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Terong
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Terong')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Toge
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Toge')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Wortel
import os
folder_path = ('/content/drive/MyDrive/DEBUSA/training/Wortel')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
from pathlib import Path
train_dir = Path('/content/drive/MyDrive/DEBUSA/training')

# Mendapatkan daftar filepaths dan labels untuk dataset dan data uji
#Get filepaths and labels
filepaths = list(train_dir.glob(r'**/*.jpg')) + list(train_dir.glob(r'**/*.JPG')) + list(train_dir.glob(r'**/*.jpeg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
import pandas as pd
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
train_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
train_df = train_df.sample(frac=1).reset_index(drop = True)

# Show the result
train_df.head(15)
# Out:
#                                              Filepath     Label
# 0   /content/drive/MyDrive/DEBUSA/training/Terong/...    Terong
# 1   /content/drive/MyDrive/DEBUSA/training/Toge/IM...      Toge
# 2   /content/drive/MyDrive/DEBUSA/training/Terong/...    Terong
# 3   /content/drive/MyDrive/DEBUSA/training/Apel/IM...      Apel
# 4   /content/drive/MyDrive/DEBUSA/training/Terong/...    Terong
# 5   /content/drive/MyDrive/DEBUSA/training/Jeruk/J...     Jeruk
# 6   /content/drive/MyDrive/DEBUSA/training/Pisang/...    Pisang
# 7   /content/drive/MyDrive/DEBUSA/training/Toge/IM...      Toge
# 8   /content/drive/MyDrive/DEBUSA/training/Jeruk/I...     Jeruk
# 9   /content/drive/MyDrive/DEBUSA/training/Kangkun...  Kangkung
# 10  /content/drive/MyDrive/DEBUSA/training/Mangga/...    Mangga
# 11  /content/drive/MyDrive/DEBUSA/training/Mangga/...    Mangga
# 12  /content/drive/MyDrive/DEBUSA/training/Mangga/...    Mangga
# 13  /content/drive/MyDrive/DEBUSA/training/Brokoli...   Brokoli
# ...

# %%
#cek label
from pathlib import Path
test_dir = Path('/content/drive/MyDrive/DEBUSA/testing')

# Mendapatkan daftar filepaths dan labels untuk dataset dan data uji
#Get filepaths and labels
filepaths = list(test_dir.glob(r'**/*.jpg')) + list(test_dir.glob(r'**/*.JPG')) + list(test_dir.glob(r'**/*.jpeg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
import pandas as pd
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
test_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
test_df = test_df.sample(frac=1).reset_index(drop = True)

# Show the result
test_df.head(15)
# Out:
#                                              Filepath     Label
# 0   /content/drive/MyDrive/DEBUSA/testing/Apel/IMG...      Apel
# 1   /content/drive/MyDrive/DEBUSA/testing/Kangkung...  Kangkung
# 2   /content/drive/MyDrive/DEBUSA/testing/Jeruk/IM...     Jeruk
# 3   /content/drive/MyDrive/DEBUSA/testing/Wortel/1...    Wortel
# 4   /content/drive/MyDrive/DEBUSA/testing/Pisang/I...    Pisang
# 5   /content/drive/MyDrive/DEBUSA/testing/Mangga/6...    Mangga
# 6   /content/drive/MyDrive/DEBUSA/testing/Apel/IMG...      Apel
# 7   /content/drive/MyDrive/DEBUSA/testing/Kangkung...  Kangkung
# 8   /content/drive/MyDrive/DEBUSA/testing/Apel/Ima...      Apel
# 9   /content/drive/MyDrive/DEBUSA/testing/Apel/IMG...      Apel
# 10  /content/drive/MyDrive/DEBUSA/testing/Wortel/I...    Wortel
# 11  /content/drive/MyDrive/DEBUSA/testing/Jeruk/Im...     Jeruk
# 12  /content/drive/MyDrive/DEBUSA/testing/Jeruk/IM...     Jeruk
# 13  /content/drive/MyDrive/DEBUSA/testing/Kangkung...  Kangkung
# ...

# %%
#cek label
from pathlib import Path
val_dir = Path('/content/drive/MyDrive/DEBUSA/validation')

# Mendapatkan daftar filepaths dan labels untuk dataset dan data uji
#Get filepaths and labels data testing
filepaths_val = list(val_dir.glob(r'**/*.jpg')) + list(val_dir.glob(r'**/*.JPG')) + list(val_dir.glob(r'**/*.jpeg'))
labels_val = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths_val))

# %%
import pandas as pd
filepaths3 = pd.Series(filepaths_val, name='Filepath').astype(str)
labels3 = pd.Series(labels_val, name='Label')

# Concatenate filepaths and labels
val_df = pd.concat([filepaths3, labels3], axis=1)

# Shuffle the DataFrame and reset index
val_df = val_df.sample(frac=1).reset_index(drop = True)

# Show the result
val_df.head(15)
# Out:
#                                              Filepath       Label
# 0   /content/drive/MyDrive/DEBUSA/validation/Pisan...      Pisang
# 1   /content/drive/MyDrive/DEBUSA/validation/Straw...  Strawberry
# 2   /content/drive/MyDrive/DEBUSA/validation/Straw...  Strawberry
# 3   /content/drive/MyDrive/DEBUSA/validation/Apel/...        Apel
# 4   /content/drive/MyDrive/DEBUSA/validation/Straw...  Strawberry
# 5   /content/drive/MyDrive/DEBUSA/validation/Pisan...      Pisang
# 6   /content/drive/MyDrive/DEBUSA/validation/Toge/...        Toge
# 7   /content/drive/MyDrive/DEBUSA/validation/Kangk...    Kangkung
# 8   /content/drive/MyDrive/DEBUSA/validation/Toge/...        Toge
# 9   /content/drive/MyDrive/DEBUSA/validation/Straw...  Strawberry
# 10  /content/drive/MyDrive/DEBUSA/validation/Worte...      Wortel
# 11  /content/drive/MyDrive/DEBUSA/validation/Kangk...    Kangkung
# 12  /content/drive/MyDrive/DEBUSA/validation/Apel/...        Apel
# ...

# %%
# Menampilkan beberapa contoh dataset dari directory training
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(train_df.Filepath[i]))
    ax.set_title(train_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Menampilkan beberapa contoh dataset dari directory training
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(val_df.Filepath[i]))
    ax.set_title(val_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Menampilkan beberapa contoh dataset dari directory training
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath[i]))
    ax.set_title(test_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = train_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()
# Out:
# <ipython-input-25-67f49b6db74c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = vc.index, y = vc, palette = "rocket")

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = val_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()
# Out:
# <ipython-input-26-dde8c6bef98d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = vc.index, y = vc, palette = "rocket")

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = test_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()
# Out:
# <ipython-input-27-321982c41b0e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = vc.index, y = vc, palette = "rocket")

# %%
print("Jumlah train Apel :", len(os.listdir(train_Apel)))
print("Jumlah val Apel :", len(os.listdir(validation_Apel)))
print("Jumlah testing Apel :", len(os.listdir(testing_Apel)))

print("Jumlah train Brokoli :", len(os.listdir(train_Brokoli)))
print("Jumlah val Brokoli :", len(os.listdir(validation_Brokoli)))
print("Jumlah testing Brokoli :", len(os.listdir(testing_Brokoli)))

print("Jumlah train Jeruk :", len(os.listdir(train_Jeruk)))
print("Jumlah val Jeruk :", len(os.listdir(validation_Jeruk)))
print("Jumlah testing Jeruk :", len(os.listdir(testing_Jeruk)))

print("Jumlah train Kangkung :", len(os.listdir(train_Kangkung)))
print("Jumlah val Kangkung :", len(os.listdir(validation_Kangkung)))
print("Jumlah testing Kangkung :", len(os.listdir(testing_Kangkung)))

print("Jumlah train Mangga :", len(os.listdir(train_Mangga)))
print("Jumlah val Mangga :", len(os.listdir(validation_Mangga)))
print("Jumlah testing Mangga :", len(os.listdir(testing_Mangga)))

print("Jumlah train Pisang :", len(os.listdir(train_Pisang)))
print("Jumlah val Pisang :", len(os.listdir(validation_Pisang)))
print("Jumlah testing Pisang :", len(os.listdir(testing_Pisang)))

print("Jumlah train Strawberry :", len(os.listdir(train_Strawberry)))
print("Jumlah val Strawberry :", len(os.listdir(validation_Strawberry)))
print("Jumlah testing Strawberry :", len(os.listdir(testing_Strawberry)))

print("Jumlah train Terong :", len(os.listdir(train_Terong)))
print("Jumlah val Terong :", len(os.listdir(validation_Terong)))
print("Jumlah testing Terong :", len(os.listdir(testing_Terong)))

print("Jumlah train Toge :", len(os.listdir(train_Toge)))
print("Jumlah val Toge :", len(os.listdir(validation_Toge)))
print("Jumlah testing Toge :", len(os.listdir(testing_Toge)))

print("Jumlah train Wortel :", len(os.listdir(train_Wortel)))
print("Jumlah val Wortel :", len(os.listdir(validation_Wortel)))
print("Jumlah testing Wortel :", len(os.listdir(testing_Wortel)))
# Out:
# Jumlah train Apel : 400
# Jumlah val Apel : 100
# Jumlah testing Apel : 50
# Jumlah train Brokoli : 400
# Jumlah val Brokoli : 100
# Jumlah testing Brokoli : 50
# Jumlah train Jeruk : 400
# Jumlah val Jeruk : 100
# Jumlah testing Jeruk : 50
# Jumlah train Kangkung : 400
# Jumlah val Kangkung : 100
# Jumlah testing Kangkung : 50
# Jumlah train Mangga : 400
# Jumlah val Mangga : 100
# Jumlah testing Mangga : 50
# Jumlah train Pisang : 400
# Jumlah val Pisang : 100
# Jumlah testing Pisang : 50
# Jumlah train Strawberry : 400
# Jumlah val Strawberry : 100
# Jumlah testing Strawberry : 50
# Jumlah train Terong : 400
# Jumlah val Terong : 100
# Jumlah testing Terong : 50
# Jumlah train Toge : 400
# Jumlah val Toge : 100
# Jumlah testing Toge : 50
# Jumlah train Wortel : 400
# Jumlah val Wortel : 100
# Jumlah testing Wortel : 50

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
       rescale=1./255
    )
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         target_size=(224,224),
                                         batch_size=32,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=val_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         target_size=(224,224),
                                         batch_size=32,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )


uji_data = test_datagen.flow_from_dataframe(dataframe=test_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         target_size=(224,224),
                                         batch_size=32,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# Out:
# Found 4000 validated image filenames belonging to 10 classes.
# Found 1000 validated image filenames belonging to 10 classes.
# Found 499 validated image filenames belonging to 10 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    horizontal_flip=True)
validasi_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
batch_size=32

train_generator = train_datagen.flow_from_directory(train_dir,
                                         target_size=(224,224),
                                         batch_size=batch_size,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                         )
val_generator = train_datagen.flow_from_directory(validation_dir,
                                         target_size=(224,224),
                                         batch_size=batch_size,
                                         class_mode = 'categorical'
                                         )
# Out:
# Found 4000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
# Load InceptionV3 pre-trained on ImageNet data
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
base_model.trainable = False
# Out:
# ...
# 87910968/87910968 [==============================] - 1s 0us/step

# %%
# Add custom classification layers
model = tf.keras.Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.3, seed=112),
    Dense(512, activation='relu'),
    Dropout(0.5, seed=112),
    Dense(10, activation='softmax')
])

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0005)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# ...
# Total params: 22464042 (85.69 MB)
# Trainable params: 661258 (2.52 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n/batch_size,
    epochs=10,
    validation_data=val_generator,
    validation_steps=val_generator.n/batch_size,
    verbose=1,
)
# Out:
# Epoch 1/10
#  91/125 [====================>.........] - ETA: 3:02 - loss: 0.0765 - accuracy: 0.9753
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:3167: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 125/125 [==============================] - 840s 7s/step - loss: 0.0787 - accuracy: 0.9753 - val_loss: 0.0565 - val_accuracy: 0.9840
# Epoch 2/10
# 125/125 [==============================] - 871s 7s/step - loss: 0.0641 - accuracy: 0.9785 - val_loss: 0.0634 - val_accuracy: 0.9790
# Epoch 3/10
# 125/125 [==============================] - 840s 7s/step - loss: 0.0682 - accuracy: 0.9820 - val_loss: 0.0592 - val_accuracy: 0.9860
# Epoch 4/10
# 125/125 [==============================] - 838s 7s/step - loss: 0.0542 - accuracy: 0.9822 - val_loss: 0.0339 - val_accuracy: 0.9880
# Epoch 5/10
# ...

# %%
 # %matplotlib inline

 import matplotlib.image as mpig
 import matplotlib.pyplot as plt

 acc = history.history['accuracy']
 val_acc = history.history['val_accuracy']
 loss = history.history['loss']
 val_loss = history.history['val_loss']

 epochs = range(len(acc))

 plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
 plt.plot(epochs, val_acc, 'b', label = 'Validation Accuracy')
 plt.title('Training and Validation accuracy')
 plt.legend(loc = 'best')
 plt.show()

 plt.plot(epochs, loss, 'r', label = 'Training Loss')
 plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
 plt.title('Training and Validation accuracy')
 plt.legend(loc = 'best')
 plt.show()

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Predict on validation data
val_predictions = model.predict(val_generator, steps=val_generator.n / batch_size)

# Get the true labels
val_true_labels = val_generator.classes

# If the model outputs probabilities, convert them to class labels
val_pred_labels = np.argmax(val_predictions, axis=1)

# Calculate precision
precision = precision_score(val_true_labels, val_pred_labels, average='weighted')

# Calculate recall
recall = recall_score(val_true_labels, val_pred_labels, average='weighted')

# Calculate F1 score
f1 = f1_score(val_true_labels, val_pred_labels, average='weighted')

# Calculate confusion matrix
confusion_mat = confusion_matrix(val_true_labels, val_pred_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', xticklabels=val_generator.class_indices.keys(), yticklabels=val_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 31/31 [==============================] - 172s 5s/step

# %%
# Print classification report
print(classification_report(val_true_labels, val_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.08      0.08      0.08       100
#            1       0.08      0.08      0.08       100
#            2       0.09      0.09      0.09       100
#            3       0.11      0.11      0.11       100
#            4       0.06      0.06      0.06       100
#            5       0.14      0.14      0.14       100
#            6       0.13      0.13      0.13       100
#            7       0.10      0.10      0.10       100
#            8       0.14      0.14      0.14       100
#            9       0.08      0.08      0.08       100
#
#     accuracy                           0.10      1000
#    macro avg       0.10      0.10      0.10      1000
# weighted avg       0.10      0.10      0.10      1000

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files
import os
import matplotlib.pyplot as plt


uploaded = files.upload()

for fn in uploaded.keys():
    # Predicting images
    path = fn
    img = image.load_img(path, target_size=(224, 224))
    imgplot = plt.imshow(img)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = x / 255.0  # Normalize the image (if your model expects normalized input)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=10)

    print(fn)

    class_list = os.listdir(train_dir)
    num_classes = len(class_list)  # Determine the number of classes

    # Find the index of the maximum value in the predictions
    predicted_class_index = np.argmax(classes[0])

    # Print the predicted class
    if predicted_class_index < num_classes:
        print('This image belongs to class', class_list[predicted_class_index])
    else:
        print('Predicted class index is out of bounds:', predicted_class_index)
# Out:
#      <input type="file" id="files-6da3d5b0-750c-4c60-b9a5-a8ce5f8356c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6da3d5b0-750c-4c60-b9a5-a8ce5f8356c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files
import os
import matplotlib.pyplot as plt


uploaded = files.upload()

for fn in uploaded.keys():
    # Predicting images
    path = fn
    img = image.load_img(path, target_size=(224, 224))
    imgplot = plt.imshow(img)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = x / 255.0  # Normalize the image (if your model expects normalized input)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=10)

    print(fn)

    class_list = os.listdir(train_dir)
    num_classes = len(class_list)  # Determine the number of classes

    # Find the index of the maximum value in the predictions
    predicted_class_index = np.argmax(classes[0])

    # Print the predicted class
    if predicted_class_index < num_classes:
        print('This image belongs to class', class_list[predicted_class_index])
    else:
        print('Predicted class index is out of bounds:', predicted_class_index)
# Out:
#      <input type="file" id="files-d54a1c37-da48-470e-a08b-3f76b8349a2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d54a1c37-da48-470e-a08b-3f76b8349a2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pickle

# Menyimpan model ke file .bin
with open('/content/drive/MyDrive/DEBUSA/InceptionV3model.bin', 'wb') as file:
    pickle.dump(model, file)
print("Model saved as .bin.")
# Out:
# Model saved as .bin.

# %%
import json

# Menyimpan arsitektur model ke file .json
model_json = model.to_json()
with open('/content/drive/MyDrive/DEBUSA/InceptionV3/InceptionV3model.json', 'w') as json_file:
    json_file.write(model_json)
print("Model architecture saved as .json.")

# Menyimpan bobot model ke file .h5
model.save_weights('/content/drive/MyDrive/DEBUSA/InceptionV3/InceptionV3model_weights.h5')
print("Model weights saved as .h5.")
# Out:
# Model architecture saved as .json.
# Model weights saved as .h5.

# %%
model.save('/content/drive/MyDrive/DEBUSA/InceptionV3model.h5')
print("Model saved.")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved.
